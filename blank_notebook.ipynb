# %%
from fabric_test.utils import filter_even_numbers# Example usageif __name__ == '__main__':    sample_list = list(range(1, 11))    even_numbers = filter_even_numbers(sample_list)    print('Even numbers:', even_numbers)
